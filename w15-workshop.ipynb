# %% [markdown]
# Nathan Michalewicz

# %% [markdown]
# # Title of Paper

# %% [markdown]
# Introduction to the question. I'm intersted in stuff. This is importa. Arg.

# %% [markdown]
# The data we work with ....

# %%
import pandas as pd
import matplotlib.pyplot as plt, seaborn as sns
import scipy.stats as stats
# https://raw.githubusercontent.com/dataprofessor/
# data/refs/heads/master/penguins_cleaned.csv

url = "https://raw.githubusercontent.com/dataprofessor/data/refs/heads/master/penguins_cleaned.csv"

df = pd.read_csv(url)
# df.head(1)

# %% [markdown]
# The first question is understanding the relationship between passes and shots. [Something about why this is important.]. How did we filter the data. Shots are determined by eventNmae. ther eis no correlation. Fig. 1. shows a p value of {whatever}...

# %%
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(5,3))
 
r,p = stats.pearsonr(df["bill_length_mm"], df["bill_depth_mm"])
r2 = r**2

text = f"""r={r:.4f}
p={p:.4f}
r2={r2:.4f}"""

reg = sns.regplot(
    data=df, 
    x="bill_length_mm", 
    y="bill_depth_mm",
    line_kws={"color": "red", "label": "Line of best fit."},
    ax=ax1
    )
ax1.text(
    x=0.1, 
    y=0.1, 
    s=text, 
    transform=plt.gca().transAxes, 
    bbox={"boxstyle":"round,pad=0.5","fc": "white"})
plt.suptitle("Fig.1", y=1.1)
# plt.title("Fig 1: Correlation between Bill Length and Bill Depth")
    # xlabel="Bill Length (mm)",
    # ylabel="Bill Depth (mm)"
    # )
plt.legend()
plt.show()
# Out:
# C:\Users\michalewiczn\AppData\Local\Temp\ipykernel_4408\1351662562.py:28: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
